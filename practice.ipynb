# %%
print("Hello world")
# Out:
# Hello world

# %%
print("hello world")
# Out:
# hello world

# %%
lst=[10,20,30,40,50]
print(lst)
# Out:
# [10, 20, 30, 40, 50]

# %%
for i in range (len(lst)):
    print(lst[i])
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
print(lst[0])
# Out:
# 10

# %%
lst[0]=2000
lst
# Out:
# [2000, 20, 30, 40, 50]

# %%
lst.insert(1,3000)
lst.print(lst)
# Out:
# [2000, 3000, 20, 30, 40, 50]

# %%
lst.append(4000)
print(lst)
# Out:
# [2000, 3000, 20, 30, 40, 50, 4000]

# %%
lst.extend([1,2,3,])
print(lst)
# Out:
# [2000, 3000, 20, 30, 40, 50, 4000, 1, 2, 3]

# %%
lst.pop(2)
print(lst)
# Out:
# [2000, 3000, 30, 40, 50, 4000, 1, 2, 3]

# %%
lst.remove(4000)
print(lst)
# Out:
# [2000, 3000, 30, 40, 50, 1, 2, 3]

# %%
lst.sort()
print(lst)
# Out:
# [1, 2, 3, 30, 40, 50, 2000, 3000]

# %%
#check the palindrome
lst=['racecar','madam','level','hello','world']
for i in lst:   
    if i==i[::-1]:
        print(i,"is a palindrome")
    else:
        print(i,"is not a palindrome")
# Out:
# racecar is a palindrome
# madam is a palindrome
# level is a palindrome
# hello is not a palindrome
# world is not a palindrome

# %%
str=("kanak","hello","world","level")
for i in str:
    if
