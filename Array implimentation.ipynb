# %%
arr=[
    [10,20,30],
    [40,50,60],
    [70,80,90]
]
print(arr)
# Out:
# [[10, 20, 30], [40, 50, 60], [70, 80, 90]]

# %%
print(arr[0][0])
print(arr[1][2])
print(arr[2][1])
# Out:
# 10
# 60
# 80
